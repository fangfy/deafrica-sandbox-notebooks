# %%
import datacube

dc=datacube.Datacube()
mrvbf = dc.load(product="dem_srtm_deriv", measurements=["mrvbf"], dask_chunks={'x':2000, 'y':2000}, 
                resolution=(-2000,2000)).mrvbf.squeeze()

# %%
mrvbf = c.compute()

# %%
mrvbf_7 = mrvbf.where(mrvbf==7)

# %%
mrvbf_7.plot(robust=True,figsize=(10,10))
